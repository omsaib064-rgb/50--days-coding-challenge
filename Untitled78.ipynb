# %%
policy_ids = [101, 102, 103, 104, 105, 106]
claim_amounts = [5000, 15000, 7000, 20000, 3000, 12000]
claim_status = ["Approved", "Rejected", "Approved", "Approved", "Rejected", "Approved"]

total_approved = 0

for i in range(len(claim_status)):
    if claim_status[i] == "Approved":
        total_approved += claim_amounts[i]

print(total_approved)
# Out:
# 44000

# %%
 Task 2: Count Rejected Claims 
Find how many claims are Rejected.

# %%
claim_status = ["Approved", "Rejected", "Approved", "Approved", "Rejected", "Approved"]

rejected_count = claim_status.count("Rejected")

print(rejected_count)
# Out:
# 2

# %%
3: High Value Claims (> ₹10,000)

# %%
high_value_policies = []

for i in range(len(claim_amounts)):
    if claim_amounts[i] > 10000:
        high_value_policies.append(policy_ids[i])

print("High Value Policy IDs:", high_value_policies)
# Out:
# High Value Policy IDs: [102, 104, 106]

# %%
4: Average Age of Approved Customers

# %%
claim_status = ["Approved", "Rejected", "Approved", "Approved", "Rejected", "Approved"]
customer_age = [25, 45, 35, 50, 23, 40]

total_age = 0
count = 0

for i in range(len(claim_status)):
    if claim_status[i] == "Approved":
        total_age += customer_age[i]
        count += 1

average_age = total_age / count

print(average_age)
# Out:
# 37.5

# %%
Task 5: Risk Category Tagging 
Create a new list called risk_category: 
• Age < 30 → "Low Risk"  
• Age 30–45 → "Medium Risk"  
• Age > 45 → "High Risk"

# %%
customer_age = [25, 45, 35, 50, 23, 40]

risk_category = []

for age in customer_age:
    if age < 30:
        risk_category.append("Low Risk")
    elif 30 <= age <= 45:
        risk_category.append("Medium Risk")
    else:
        risk_category.append("High Risk")

print(risk_category)
# Out:
# ['Low Risk', 'Medium Risk', 'Medium Risk', 'High Risk', 'Low Risk', 'Medium Risk']
